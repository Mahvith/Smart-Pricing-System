# %%
# %pip install numpy pandas re os requests json
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd

# %%
DATASET_FOLDER = './dataset/'
train = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, 'test.csv'))
sample_test = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test.csv'))
sample_test_out = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test_out.csv'))

# %%
# train.iloc[1][1]
# print(train.loc[0][1])



# for i in range(0,10):
#     print(train.at[2, "catalog_content"])

# %%
n = train.shape[0]  # 75000
example_indices = list(map(int, np.random.choice(n, size=5, replace=False)))
example_indices
# Out:
# [36324, 47413, 21970, 5190, 17473]

# %%
for i in example_indices:
    print(f"Example {i} of {n}")
    print(train.at[i, "catalog_content"])
    # print(train.iloc[i])
    print()
# Out:
# Example 36324 of 75000
# Item Name: Licorice Root (Certified Organic) Tea (25 tea bags, ZIN: 517742)
# Bullet Point 1: Licorice Root (Certified Organic) Tea (25 tea bags, ZIN: 517742)
# Bullet Point 2: No fillers.
# Bullet Point 3: Manufacturer: TerraVita
# Bullet Point 4: Size: 25 tea bags
# Bullet Point 5: Herbal Tea Bags - Packed in a convenient upright pouch!
# Product Description: Licorice Root (Certified Organic) Tea (25 tea bags, ZIN: 517742)<BR><BR>Packaged in the United States in a GMP certified facility (Good Manufacturing Practice).<BR><BR>No fillers.<BR><BR>Manufacturer: TerraVita<BR><BR>Size: 25 tea bags<BR><BR>Herbal Tea Bags - Packed in a convenient upright pouch!<BR><BR>Ingredients: Licorice Root (Certified Organic)
# Value: 25.0
# Unit: Count
#
#
# Example 47413 of 75000
# Item Name: Dr. Oetker Gustin Feine Speisestärke 400 g
# Bullet Point 1: PRECISION COOKING 🍳: Achieve precise consistency and smooth textures in your sauces, gravies, and desserts.
# ...

# %%
# from google import genai
# from pydantic import BaseModel

# # dataset

# df = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))

# # Pydantic model for structured output

# class DataTypePrediction(BaseModel):
#     sample_id: int
#     data_type: int

# client = genai.Client(api_key="AIzaSyBz-HUG4HHuJd8VNmmL0uH2Z8EEstSVO7w")

# # Prepare prompt for LLM
# contents = "For each product, extract the \n value: XX  \n from the catalog description, Return JSON with sample_id and value "

# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents = contents + "\nData:\n" + df.to_json(orient="records"),
#     config ={
#         "response_mime_type": "application/json",
#         "response_schema": list[DataTypePrediction],
#     }
# )

# # Extract predictions
# predictions = pd.DataFrame([item.dict() for item in response.result])

# # Merge with original dataframe
# df = df.merge(predictions, on="sample_id")
# print(df)

# %%
# import requests
# import json

# op = []

# # API endpoint for Ollama
# url = "http://localhost:11434/api/generate"

# # The model you want to use (change if needed)
# model_name = "gemma3:4b"

# system_prompt =  """
#     IF YOU DONT ADHERE TO INSTRUCTIONS I'LL DIE.
#     Extract structured information from the following text and return only valid JSON.
    
#     The JSON should follow this schema exactly:
        
#     output:
#     {
#         "item_name": string,
#         "value": float,
#         "unit": string
#     }
        
#     Here's an example:
    
#     input: 
    
#     Example 1

#         Item Name: Salerno Cookies, The Original Butter Cookies, 8 Ounce (Pack of 4)
#         Bullet Point 1: Original Butter Cookies: Classic butter cookies made with real butter
#         Bullet Point 2: Variety Pack: Includes 4 boxes with 32 cookies total
#         Bullet Point 3: Occasion Perfect: Delicious cookies for birthdays, weddings, anniversaries
#         Bullet Point 4: Shareable Treats: Fun to give and enjoy with friends and family
#         Bullet Point 5: Salerno Brand: Trusted brand of delicious butter cookies since 1925
#         Value: 32.0
#         Unit: Ounce
        
#         output:
#         {
#             "item_name": Salerno Cookies,
#             "value": 32.0,
#             "unit": Ounce
#         }
        
#     Example 2
    
#         Item Name: Weldon Flavorings, Blueberry Unsweetened Tea/Water Flavoring (Includes Pump)
#         Product Description: Looking for a way to enjoy your regular tea while on a low-carb / low-calorie diet? Do you take your tea black and unsweetened, but also enjoy flavored tea? Each 4 oz bottle of our product flavors 118/8 oz. cups, and contains NO sweeteners, calories, carbs, fat, sodium or caffeine. Our Blueberry Tea flavoring has a rich and smooth blueberry flavor and can be used in hot or cold beverages. Simply add 2-4 drops per 8 oz of tea, depending on your preference. All flavors are not pre-sweetened; you can enjoy flavored tea unsweetened or sweetened to your own taste. You can also use it to flavor an infinite variety of foods and beverages such as water, smoothies, fruit juice, yogurt, salad dressing, cocktails, mocktails, and so much more. Our versatile blueberry tea concentrate can also be used to make blueberry muffins, scones, pancakes, waffles, and much more. These are great for the home, office, or hotel. They are also perfect for coffee shops, restaurants, and cafes.
#         Value: 1.0
#         Unit: Count
        
#         output:
#         {
#             "item_name": Salerno Cookies,
#             "value": 32.0,
#             "unit": Ounce
#         }

#     Example 3

#         Item Name: Blue Diamond Almonds Smokehouse 6 Oz Pack of 2
#         Bullet Point 1: Blue Diamond Almonds Smokehouse
#         Bullet Point 2: Smart Eating
#         Bullet Point 3: 6 oz package. Set of 2
#         Bullet Point 4: Irresistible Snacking
#         Bullet Point 5: Kosher
#         Product Description: Blue Diamond Almonds, Smokehouse, 6 Oz. Set of 2
#         Value: 12.0
#         Unit: Ounce
        
#         output:
#         {
#             "item_name": Salerno Cookies,
#             "value": 32.0,
#             "unit": Ounce
#         }

#     Example 4
        
#         Item Name: Super Garden Freeze Dried Garlic Granules | 100% Natural, No Artificial Additives or Preservatives | Perfect Granulated Garlic for Cooking, Seasoning, and Gourmet Dishes | Long shelf Life Freeze Dried Spices | Space Food | 2.12oz
#         Bullet Point 1: UNLEASH EXTRAORDINARY FLAVORS: Elevate your meals with Super Garden's aromatic freeze-dried garlic seasoning. It's the secret ingredient that transforms ordinary dishes into extraordinary culinary experiences, perfect for flavor enthusiasts.
#         Bullet Point 2: CULINARY MAGIC IN EVERY DISH: Discover how our freeze-dried herbs, including organic garlic flakes, enhance every meal. Whether vegan, vegetarian, or a meat lover, it's perfect for salads, stir-fries, soups, pastas, and savory pies – explore endless possibilities and awaken your taste buds.
#         Bullet Point 3: HEALTH BOOST IN EVERY BITE: Our nutrient-packed freeze-dried garlic granulated seasoning is more than just a seasoning – it's a health-boosting powerhouse! Rich in vitamins and antioxidants, it nourishes your body while enhancing flavors. Sourced from trusted local farmers, it's the natural choice for vibrant, savory dishes.
ea *1 x Premium Jasmine Tea *1 x Premium Black Tea *1 x Premium Thai Tea *40 x Boba Straws *Recipe Cards One party size kit can make 50+ drinks and 18-20 servings tapioca pearls (boba) Premium Matcha: Organic Matcha. Made in Japan Premium Peach Oolong Tea: Organic Oolong Tea, Organic Rosehips, Organic Marigolds, Natural Flavors. Blended in The United States Premium Hibiscus Island Tea: Organic Hibiscus Tea, Organic Rosehips, Natural Flavors. Blended in The United States. Premium Black Tea: Black Tea. Made in Taiwan Premium Jasmine Tea: Jasmine Green Tea Leaves, Jasmine, Jasmine Flavor. Made in Taiwan Premium Thai Tea: Black Tea Leaves, FDC Yellow6. Made in Thailand Premium Earl Grey Lavender Tea: Organic black tea, natural oil of bergamot and organic lavender flowers. Blended in The United States.
#         Value: 1.0
#         Unit: Count

#         output:
#         {
#             "item_name": Salerno Cookies,
#             "value": 32.0,
#             "unit": Ounce
#         }

#     Example 6
        
#         Item Name: Community Coffee Sugar Bulk Pack, 1000 Count
#         Bullet Point 1: Community Coffee Sugar: For the perfect amount of sweetness, try Community Coffee Sugar. Our individual sugar packs are a great complement to help you enjoy a rich, smooth cup of Community Coffee
#         Bullet Point 2: A Touch of Sweetness: Our extra-fine granulated cane sugar comes in an individual serving packs. Perfect for offices, businesses and foodservice operations
#         Bullet Point 3: Community Is Everything: From using responsibly-sourced coffee beans to programs that support military service members, local schools and more, Community Coffee gives back to our partners and local communities in every way we can
#         Bullet Point 4: More Than Coffee: We offer high quality sugar, creamer, flavored creamer & more so you can enjoy your coffee to your liking. Make your drink as strong or as sweet as you like it with Community Coffee
#         Bullet Point 5: Quality Assured: All of our coffee beans go through a rigorous scoring system for body, balance, flavor and aroma. Only then can they be considered fit to bear the Community Coffee name
#         Value: 1000.0
#         Unit: Count
        
#         output:
#         {
#             "item_name": Salerno Cookies,
#             "value": 32.0,
#             "unit": Ounce
#         }
    
#     Return only the JSON, nothing else.
    
# """

# for i in range(0, 10):
#     # Your input prompt
#     payload = {
#         "model": model_name,
#         # "prompt": "Write a short poem about the moon in winter.",
        
#         "prompt":system_prompt + train.iloc[i][1],
#         "stream": False  # Set True if you want streaming response
#     }

#     # Send POST request
#     response = requests.post(url, json=payload)

#     # Parse response
#     if response.status_code == 200:
#         data = response.json()
#         print(data.get("response", ""))
#     else:
#         print("Error:", response.status_code, response.text)
        
        
# df = pd.json_normalize(op)
# df.head()

# %%
# import requests
# import json
# import pandas as pd
# import re  # For regex extraction

# op = []

# url = "http://localhost:11434/api/generate"
# model_name = "gemma3:4b"

# system_prompt =  """
#     IF YOU DONT ADHERE TO INSTRUCTIONS I'LL DIE.
#     Extract structured information from the following text and return only valid JSON.
    
#     The JSON should follow this schema exactly:
        
#     output:
#     {
#         "product_name": string,
#         "unit": string,
#         "quantity": int,
#         "vol": int,
#         "value": float   
#     }
        
#     Here are examples:
    
#     Example 1
#         input:
#         Item Name: Salerno Cookies, The Original Butter Cookies, 8 Ounce (Pack of 4)
#         Bullet Point 1: Original Butter Cookies: Classic butter cookies made with real butter
#         Bullet Point 2: Variety Pack: Includes 4 boxes with 32 cookies total
#         Bullet Point 3: Occasion Perfect: Delicious cookies for birthdays, weddings, anniversaries
#         Bullet Point 4: Shareable Treats: Fun to give and enjoy with friends and family
#         Bullet Point 5: Salerno Brand: Trusted brand of delicious butter cookies since 1925
#         Value: 32.0
#         Unit: Ounce
        
#         output:
#         {
#             "product_name": Salerno Cookies,
#             "unit": Ounce,
#             "quantity": 4,
#             "vol": 8,
#             "value": 32.0
#         }
    
#     Example 2
#         input:
#         Item Name: Weldon Flavorings, Blueberry Unsweetened Tea/Water Flavoring (Includes Pump)
#         Product Description: Looking for a way to enjoy your regular tea while on a low-carb / low-calorie diet? Do you take your tea black and unsweetened, but also enjoy flavored tea? Each 4 oz bottle of our product flavors 118/8 oz. cups, and contains NO sweeteners, calories, carbs, fat, sodium or caffeine. Our Blueberry Tea flavoring has a rich and smooth blueberry flavor and can be used in hot or cold beverages. Simply add 2-4 drops per 8 oz of tea, depending on your preference. All flavors are not pre-sweetened; you can enjoy flavored tea unsweetened or sweetened to your own taste. You can also use it to flavor an infinite variety of foods and beverages such as water, smoothies, fruit juice, yogurt, salad dressing, cocktails, mocktails, and so much more. Our versatile blueberry tea concentrate can also be used to make blueberry muffins, scones, pancakes, waffles, and much more. These are great for the home, office, or hotel. They are also perfect for coffee shops, restaurants, and cafes.
#         Value: 1.0
#         Unit: Count
        
#         output:
#         {
#             "product_name": Weldon Flavorings,
#             "unit": Ounce,
#             "quantity": 1,
#             "vol": 4,
#             "value": 1.0
#         }

#     Example 3
#         input:
#         Item Name: Blue Diamond Almonds Smokehouse 6 Oz Pack of 2
#         Bullet Point 1: Blue Diamond Almonds Smokehouse
#         Bullet Point 2: Smart Eating
#         Bullet Point 3: 6 oz package. Set of 2
#         Bullet Point 4: Irresistible Snacking
#         Bullet Point 5: Kosher
#         Product Description: Blue Diamond Almonds, Smokehouse, 6 Oz. Set of 2
#         Value: 12.0
#         Unit: Ounce
        
#         output:
#         {
#             "product_name": Blue Diamond Almonds,
#             "unit": Ounce,
#             "quantity": 2,
#             "vol": 6,
#             "value": 12.0
#         }

#     Example 4
#         input:
#         Item Name: Super Garden Freeze Dried Garlic Granules | 100% Natural, No Artificial Additives or Preservatives | Perfect Granulated Garlic for Cooking, Seasoning, and Gourmet Dishes | Long shelf Life Freeze Dried Spices | Space Food | 2.12oz
#         Bullet Point 1: UNLEASH EXTRAORDINARY FLAVORS: Elevate your meals with Super Garden's aromatic freeze-dried garlic seasoning. It's the secret ingredient that transforms ordinary dishes into extraordinary culinary experiences, perfect for flavor enthusiasts.
#         Bullet Point 2: CULINARY MAGIC IN EVERY DISH: Discover how our freeze-dried herbs, including organic garlic flakes, enhance every meal. Whether vegan, vegetarian, or a meat lover, it's perfect for salads, stir-fries, soups, pastas, and savory pies – explore endless possibilities and awaken your taste buds.
#         Bullet Point 3: HEALTH BOOST IN EVERY BITE: Our nutrient-packed freeze-dried garlic granulated seasoning is more than just a seasoning – it's a health-boosting powerhouse! Rich in vitamins and antioxidants, it nourishes your body while enhancing flavors. Sourced from trusted local farmers, it's the natural choice for vibrant, savory dishes.
iscus Rosehips Tea *1 x Organic Peach Oolong Tea *1 x Premium Jasmine Tea *1 x Premium Black Tea *1 x Premium Thai Tea *40 x Boba Straws *Recipe Cards One party size kit can make 50+ drinks and 18-20 servings tapioca pearls (boba) Premium Matcha: Organic Matcha. Made in Japan Premium Peach Oolong Tea: Organic Oolong Tea, Organic Rosehips, Organic Marigolds, Natural Flavors. Blended in The United States Premium Hibiscus Island Tea: Organic Hibiscus Tea, Organic Rosehips, Natural Flavors. Blended in The United States. Premium Black Tea: Black Tea. Made in Taiwan Premium Jasmine Tea: Jasmine Green Tea Leaves, Jasmine, Jasmine Flavor. Made in Taiwan Premium Thai Tea: Black Tea Leaves, FDC Yellow6. Made in Thailand Premium Earl Grey Lavender Tea: Organic black tea, natural oil of bergamot and organic lavender flowers. Blended in The United States.
#         Value: 1.0
#         Unit: Count

#         output:
#         {
#             "product_name": Premium Boba Tea Kit,
#             "unit": Ounce,
#             "quantity": 2,
#             "vol": 14,
#             "value": 1.0
#         }

#     Example 6
#         input:
#         Item Name: Community Coffee Sugar Bulk Pack, 1000 Count
#         Bullet Point 1: Community Coffee Sugar: For the perfect amount of sweetness, try Community Coffee Sugar. Our individual sugar packs are a great complement to help you enjoy a rich, smooth cup of Community Coffee
#         Bullet Point 2: A Touch of Sweetness: Our extra-fine granulated cane sugar comes in an individual serving packs. Perfect for offices, businesses and foodservice operations
#         Bullet Point 3: Community Is Everything: From using responsibly-sourced coffee beans to programs that support military service members, local schools and more, Community Coffee gives back to our partners and local communities in every way we can
#         Bullet Point 4: More Than Coffee: We offer high quality sugar, creamer, flavored creamer & more so you can enjoy your coffee to your liking. Make your drink as strong or as sweet as you like it with Community Coffee
#         Bullet Point 5: Quality Assured: All of our coffee beans go through a rigorous scoring system for body, balance, flavor and aroma. Only then can they be considered fit to bear the Community Coffee name
#         Value: 1000.0
#         Unit: Count
        
#         output:
#         {
#             "product_name": Community Coffee Sugars,
#             "unit": Count,
#             "quantity": 1000,
#             "vol": 1000,
#             "value": 1000.0
#         }
    
#     Return only the JSON, nothing else.
    
# """

# for i in range(0, 10):
#     text_input = train.iloc[i][1]  # Ensure this exists

#     payload = {
#         "model": model_name,
#         "prompt": system_prompt + "\n\n" + text_input,
#         "stream": False
#     }

#     response = requests.post(url, json=payload)

#     if response.status_code == 200:
#         data = response.json()
#         raw_output = data.get("response", "").strip()

#         # Extract JSON substring using regex
#         match = re.search(r"\{.*\}", raw_output, re.DOTALL)
#         if match:
#             json_str = match.group(0)
#             try:
#                 parsed_json = json.loads(json_str)
#                 op.append(parsed_json)
#             except json.JSONDecodeError:
#                 print(f"⚠️ Invalid JSON format for row {i}")
#                 print(json_str)
#         else:
#             print(f"⚠️ No JSON found in response for row {i}")
#             print(raw_output)

#     else:
#         print("Error:", response.status_code, response.text)

# %%
# # Combine all into DataFrame
# df = pd.json_normalize(op)
# # print(df.head(10))
# df.head(10)

# %%
# import requests
# import json
# import pandas as pd
# import re  # For regex extraction

# op = []

# url = "http://localhost:11434/api/generate"
# model_name = "gemma3:4b"

# system_prompt =  """
#     IF YOU DONT ADHERE TO INSTRUCTIONS I'LL DIE.
#     Extract structured information from the following text and return only valid JSON.
    
#     The JSON should follow this schema exactly:
        
#     output:
#     {
#         "item_name": string,
#         "unit": string,
#         "quantity": int,
#         "vol": int,
#         "value": float   
#     }
        
#     Here's an example:
#     input: 
#     Item Name: Salerno Cookies, The Original Butter Cookies, 8 Ounce (Pack of 4)
#     Bullet Point 1: Original Butter Cookies: Classic butter cookies made with real butter
#     Bullet Point 2: Variety Pack: Includes 4 boxes with 32 cookies total
#     Bullet Point 3: Occasion Perfect: Delicious cookies for birthdays, weddings, anniversaries
#     Bullet Point 4: Shareable Treats: Fun to give and enjoy with friends and family
#     Bullet Point 5: Salerno Brand: Trusted brand of delicious butter cookies since 1925
#     Value: 32.0
#     Unit: Ounce
    
#     output:
#     {
#         "item_name": Salerno Cookies,
#         "unit": Ounce,
#         "quantity": 4,
#         "vol": 8,
#         "value": 32.0
#     }
    
#     Return only the JSON, nothing else.
    
# """

# for i in range(0, 10):
#     text_input = train.iloc[i][1]  # Ensure this exists

#     payload = {
#         "model": model_name,
#         "prompt": system_prompt + "\n\n" + text_input,
#         "stream": False
#     }

#     response = requests.post(url, json=payload)

#     if response.status_code == 200:
#         data = response.json()
#         raw_output = data.get("response", "").strip()

#         # Extract JSON substring using regex
#         match = re.search(r"\{.*\}", raw_output, re.DOTALL)
#         if match:
#             json_str = match.group(0)
#             try:
#                 parsed_json = json.loads(json_str)
#                 op.append(parsed_json)
#             except json.JSONDecodeError:
#                 print(f"⚠️ Invalid JSON format for row {i}")
#                 print(json_str)
#         else:
#             print(f"⚠️ No JSON found in response for row {i}")
#             print(raw_output)

#     else:
#         print("Error:", response.status_code, response.text)

# %%
# Save each parsed JSON to CSV as soon as it's received from the LLM.
# Re-uses variables and imports already defined in earlier cells:
# - requests, json, pd, os, re, train, url, model_name, system_prompt, op
import requests
import json
import pandas as pd
import os
import re  # For regex extraction   

op = []

url = "http://localhost:11434/api/generate"
model_name = "gemma3:4b"

output_csv = os.path.join(DATASET_FOLDER, "llm_parsed_incremental.csv")

system_prompt =  """
    IF YOU DONT ADHERE TO INSTRUCTIONS I'LL DIE.
    Extract structured information from the following text and return only valid JSON.
    
    The JSON should follow this schema exactly:
        
    output:
    {
        "product_name": string,
        "unit": string,
        "quantity": int,
        "vol": int,
        "value": float   
    }
        
    Here are examples:
    
    Example 1
        input:
        Item Name: Salerno Cookies, The Original Butter Cookies, 8 Ounce (Pack of 4)
        Bullet Point 1: Original Butter Cookies: Classic butter cookies made with real butter
        Bullet Point 2: Variety Pack: Includes 4 boxes with 32 cookies total
        Bullet Point 3: Occasion Perfect: Delicious cookies for birthdays, weddings, anniversaries
        Bullet Point 4: Shareable Treats: Fun to give and enjoy with friends and family
        Bullet Point 5: Salerno Brand: Trusted brand of delicious butter cookies since 1925
        Value: 32.0
        Unit: Ounce
        
        output:
        {
            "product_name": Salerno Cookies,
            "unit": Ounce,
            "quantity": 4,
            "vol": 8,
            "value": 32.0
        }
    
    Example 2
        input:
        Item Name: Weldon Flavorings, Blueberry Unsweetened Tea/Water Flavoring (Includes Pump)
        Value: 1.0
        Unit: Count

        output:
        {
            "product_name": Premium Boba Tea Kit,
            "unit": Ounce,
            "quantity": 2,
            "vol": 14,
            "value": 1.0
        }

    Example 6
        input:
        Item Name: Community Coffee Sugar Bulk Pack, 1000 Count
        Bullet Point 1: Community Coffee Sugar: For the perfect amount of sweetness, try Community Coffee Sugar. Our individual sugar packs are a great complement to help you enjoy a rich, smooth cup of Community Coffee
        Bullet Point 2: A Touch of Sweetness: Our extra-fine granulated cane sugar comes in an individual serving packs. Perfect for offices, businesses and foodservice operations
        Bullet Point 3: Community Is Everything: From using responsibly-sourced coffee beans to programs that support military service members, local schools and more, Community Coffee gives back to our partners and local communities in every way we can
        Bullet Point 4: More Than Coffee: We offer high quality sugar, creamer, flavored creamer & more so you can enjoy your coffee to your liking. Make your drink as strong or as sweet as you like it with Community Coffee
        Bullet Point 5: Quality Assured: All of our coffee beans go through a rigorous scoring system for body, balance, flavor and aroma. Only then can they be considered fit to bear the Community Coffee name
        Value: 1000.0
        Unit: Count
        
        output:
        {
            "product_name": Community Coffee Sugars,
            "unit": Count,
            "quantity": 1000,
            "vol": 1000,
            "value": 1000.0
        }
    
    Return only the JSON, nothing else.
    
"""

# Ensure op exists
try:
    op
except NameError:
    op = []

for i in range(0, 75000):
    text_input = train.iloc[i][1]  # Ensure this exists

    payload = {
        "model": model_name,
        "prompt": system_prompt + "\n\n" + text_input,
        "stream": False
    }

    response = requests.post(url, json=payload)

    if response.status_code == 200:
        data = response.json()
        raw_output = data.get("response", "").strip()

        match = re.search(r"\{.*\}", raw_output, re.DOTALL)
        if match:
            json_str = match.group(0)
            try:
                parsed_json = json.loads(json_str)
                op.append(parsed_json)

                # Convert single parsed json to DataFrame and append to CSV
                df_row = pd.DataFrame([parsed_json])

                # If file doesn't exist write header, else append without header
                write_header = not os.path.exists(output_csv)
                df_row.to_csv(output_csv, mode="a", index=False, header=write_header)

            except json.JSONDecodeError:
                print(f"⚠️ Invalid JSON format for row {i}")
                print(json_str)
        else:
            print(f"⚠️ No JSON found in response for row {i}")
            print(raw_output)
    else:
        print("Error:", response.status_code, response.text)
# Out:
# /tmp/ipykernel_17776/3715283591.py:166: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_input = train.iloc[i][1]  # Ensure this exists
# ⚠️ Invalid JSON format for row 52
# {
#     "product_name": Carbquik Baking Mix,
#     "unit": Ounce,
#     "quantity": 3,
#     "vol": 48,
#     "value": 48.0
# }
# ⚠️ Invalid JSON format for row 72
# {
#     "product_name": McVities Milk Chocolate Digestives,
#     "unit": Count,
#     "quantity": 4,
#     "vol": 266,
#     "value": 4.0
# }
# ⚠️ Invalid JSON format for row 89
# {
#     "product_name": Mariani, Mediterranean Apricots,
#     "unit": Count,
#     "quantity": 24,
#     "vol": 24,
#     "value": 24.0
# }
# ⚠️ Invalid JSON format for row 96
# {
#     "product_name": Amoretti - Cola Extract,
#     "unit": Ounce,
#     "quantity": 2,
# ...
